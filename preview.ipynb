# %%
from overview import Overview
from sources import Sources
from authors import Authors
from affiliations import Affiliations
from countries import Countries
from documents import Words
from social_structure import SocialStructure

# %%
file = 'BiblioshinyReport-2024-02-08.xlsx'

# %%
overview = Overview()
overview.annual_scientific_production(file, dpi=100, language='ru')

# %%
sources = Sources()
sources.most_relevant_sources(file, dpi=100, language='ru')
sources.core_sources_by_bradfords_law(file, dpi=100, language='ru')
sources.sources_production_over_time(file, dpi=100, language='ru')

# %%
authors = Authors()
authors.most_relevant_authors(file, dpi=100, language='ru')
authors.authors_production_over_time(file, dpi=100, language='ru')

# %%
affiliations = Affiliations()
affiliations.most_relevant_affiliations(file, dpi=100, language='ru')
affiliations.affiliations_production_over_time(file, dpi=100, language='ru')

# %%
countries = Countries()
countries.corresponding_authors_countries(file, dpi=100, language='ru')
countries.countries_scientific_production(file, language='ru')
countries.countries_production_over_time(file, dpi=100, language='ru')
# Out:
# C:\Users\dmitr\PycharmProjects\BibliometrixPlots\countries.py:97: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
words = Words()
words.most_relevant_words(file, dpi=100, language='ru')
words.word_cloud(file, dpi=100)
words.treemap(file, dpi=100, language='ru')
words.words_frequency_over_time(file, dpi=100, language='ru')
words.trend_topics(file, dpi=100, language='ru')

# %%
social_structure = SocialStructure()
social_structure.countries_collaboration_world_map(file, language='ru')
# Out:
# C:\Users\dmitr\PycharmProjects\BibliometrixPlots\social_structure.py:38: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
